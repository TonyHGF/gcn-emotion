# %%
import torch
import matplotlib.pyplot as plt

# %%
edge_mask = torch.load("../results/edge_mask_sample.pt")
print(edge_mask.shape)   # (62, 62)
# Out:
# torch.Size([62, 62])

# %%
plt.figure(figsize=(6, 6))
plt.imshow(edge_mask.cpu(), cmap="hot")
plt.colorbar()
plt.title("Explained Spatial Connectivity")
plt.tight_layout()
plt.show()
